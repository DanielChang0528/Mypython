# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1=[1,2,3,4,5,6,7,8]
data2=[1,9,16,25,36,49,64,81]

# %%
seq=[1,2,3,4,5,6,7,8]

# %%
plt.figure(1)
plt.plot(seq,data1,'-*')
plt.figure(2)
plt.plot(seq,data2,'-*')
plt.title("Test Chart 2",fontsize=24)
plt.xlabel('x-Value',fontsize=14)
plt.ylabel('y-Value',fontsize=14)
plt.show()
